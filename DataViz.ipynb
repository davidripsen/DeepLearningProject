# %%
import matplotlib.pyplot as plt
from IPython.display import Image, display, clear_output
import numpy as np
# %matplotlib nbagg
# %matplotlib inline
import seaborn as sns
import pandas as pd
sns.set_style("whitegrid")
import pickle

# %%
# Load data
df0 = pickle.load( open( "data/aligned_GM-7792_DRD-d6b1cf27-41ed-43b6-8050-2068ef941a0aDRD-d6b1cf27-41ed-43b6-8050-2068ef941a0a_GM-7792_pass-0_cleaned.pickle", "rb" ) )
df1 = pickle.load( open( "data/aligned_GM-7792_DRD-d6b1cf27-41ed-43b6-8050-2068ef941a0aDRD-d6b1cf27-41ed-43b6-8050-2068ef941a0a_GM-7792_pass-1_cleaned.pickle", "rb" ) )

# %%
# Merge the two dataframes
df = df0.append(df1, ignore_index=True)
n, p = df.shape

## Pickle dump
# pickle.dump(df, open('data/df_merged.pickle', 'wb'))

# Show data
df
# Out:
#       IRI_mean                                       IRI_sequence  \
# 0      4.93354  [6.644882798499999, 5.5573473115, 7.666319952,...
# 1     4.696225  [5.5573473115, 7.666319952, 4.1605364705, 5.35...
# 2     4.699145  [7.666319952, 4.1605364705, 5.359907053000001,...
# 3     4.397566  [4.1605364705, 5.359907053000001, 4.5512844555...
# 4     4.400549  [5.359907053000001, 4.5512844555, 5.8527534034...
# ...        ...                                                ...
# 3825  4.837542  [1.5040751085, 4.321298265999999, 4.489471549,...
# 3826  5.670908  [4.321298265999999, 4.489471549, 5.3505552615,...
# 3827  6.120778           [4.489471549, 5.3505552615, 8.522308649]
# 3828  6.936432                        [5.3505552615, 8.522308649]
# 3829  8.522309                                      [8.522308649]
#
#                                       GM.TS_or_Distance  \
# 0     [2021-04-22 01:21:54.349000+00:00, 2021-04-22 ...
# 1     [2021-04-22 01:21:55.068000+00:00, 2021-04-22 ...
# 2     [2021-04-22 01:21:56.327000+00:00, 2021-04-22 ...
# 3     [2021-04-22 01:21:57.983000+00:00, 2021-04-22 ...
# 4     [2021-04-22 01:21:59.120000+00:00, 2021-04-22 ...
# ...                                                 ...
# 3825  [2021-04-22 02:38:46.636000+00:00, 2021-04-22 ...
# 3826  [2021-04-22 02:38:49.093000+00:00, 2021-04-22 ...
# 3827  [2021-04-22 02:38:50.917000+00:00, 2021-04-22 ...
# 3828  [2021-04-22 02:38:53.232000+00:00, 2021-04-22 ...
# 3829  [2021-04-22 02:38:53.422000+00:00, 2021-04-22 ...
#
#                                                    GM.T  \
# 0     [acc.xyz, acc.xyz, acc.xyz, acc.xyz, obd.spd_v...
# 1     [acc.xyz, acc.xyz, acc.xyz, acc.xyz, acc.xyz, ...
# 2     [acc.xyz, acc.xyz, acc.xyz, acc.xyz, acc.xyz, ...
# 3     [acc.xyz, acc.xyz, acc.xyz, acc.xyz, acc.xyz, ...
# 4     [obd.spd_veh, acc.xyz, acc.xyz, acc.xyz, acc.x...
# ...                                                 ...
# 3825  [acc.xyz, acc.xyz, obd.spd_veh, acc.xyz, obd.s...
# 3826  [acc.xyz, acc.xyz, acc.xyz, acc.xyz, obd.spd_v...
# 3827  [acc.xyz, acc.xyz, acc.xyz, obd.spd_veh, acc.x...
# 3828  [acc.xyz, acc.xyz, acc.xyz, obd.spd_veh, acc.x...
# 3829  [acc.xyz, obd.spd_veh, acc.xyz, acc.xyz, acc.x...
#
#                                              GM.lat_int  \
# 0     [55.654713308383236, 55.65471373053892, 55.654...
# 1     [55.654781462897525, 55.65478160070671, 55.654...
# 2     [55.654862308917195, 55.65486260509554, 55.654...
# 3     [55.654942544169614, 55.65494265017668, 55.654...
# 4     [55.65502238338658, 55.65502269329073, 55.6550...
# ...                                                 ...
# 3825  [55.65274301886792, 55.65274304402516, 55.6527...
# 3826  [55.652753000000004, 55.652753022727275, 55.65...
# 3827  [55.652763, 55.652763020689655, 55.65276304137...
# 3828  [55.65277408333333, 55.65277422916667, 55.6527...
# 3829  [55.65278331944444, 55.652783416666665, 55.652...
#
#                                              GM.lon_int  \
# 0     [12.486686901197604, 12.486686532934131, 12.48...
# 1     [12.48662899293286, 12.486628876325089, 12.486...
# 2     [12.486560579617835, 12.486560331210192, 12.48...
# 3     [12.486492964664311, 12.486492879858657, 12.48...
# 4     [12.486424923322684, 12.486424661341852, 12.48...
# ...                                                 ...
# 3825  [12.489080716981132, 12.489080339622642, 12.48...
# 3826  [12.48892, 12.488919613636364, 12.488919323863...
# 3827  [12.488769999999999, 12.488769689655172, 12.48...
# 3828  [12.488592708333334, 12.488590197916666, 12.48...
# 3829  [12.488433715277777, 12.488432041666666, 12.48...
#
#                                            GM.acc.xyz.z  \
# 0     [0.9727, 0.9727, 0.9727, 0.9727, 0.9922, 0.992...
# 1     [0.9727, 0.9727, 0.9727, 0.9727, 0.9727, 0.972...
# 2     [1.0391, 1.0391, 1.0391, 1.0391, 1.0391, 1.015...
# 3     [1.0391, 1.0391, 0.9805, 0.9805, 0.9805, 0.980...
# 4     [0.9492, 0.9961, 0.9961, 0.9961, 0.9961, 0.996...
# ...                                                 ...
# 3825  [0.9961, 1.0039, 1.0039, 1.0, 1.0, 0.9922, 0.9...
# 3826  [0.9961, 0.9961, 0.9961, 0.9961, 0.9961, 1.015...
# 3827  [0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.988...
# 3828  [1.0, 1.0, 1.0, 1.0, 0.9922, 0.9922, 0.9922, 0...
# 3829  [0.9805, 0.9883, 0.9883, 0.9883, 0.9883, 0.988...
#
#                                            GM.acc.xyz.y  \
# 0     [-0.1172, -0.1172, -0.1172, -0.1172, -0.1211, ...
# 1     [-0.0898, -0.0898, -0.0898, -0.0898, -0.0898, ...
# 2     [0.0273, 0.0273, 0.0273, 0.0273, 0.0273, 0.011...
# 3     [0.1016, 0.1016, 0.0898, 0.0898, 0.0898, 0.089...
# 4     [0.0859, 0.0977, 0.0977, 0.0977, 0.0977, 0.097...
# ...                                                 ...
# 3825  [0.0195, 0.0195, 0.0195, 0.0195, 0.0195, 0.023...
# 3826  [-0.0703, -0.0703, -0.0703, -0.0703, -0.0703, ...
# 3827  [-0.1016, -0.1016, -0.1016, -0.1016, -0.1016, ...
# 3828  [-0.1094, -0.1094, -0.1094, -0.1094, -0.1133, ...
# 3829  [-0.0977, -0.1016, -0.1016, -0.1016, -0.0977, ...
#
#                                            GM.acc.xyz.x  \
# 0     [0.1602, 0.1602, 0.1602, 0.1602, 0.1563, 0.156...
# 1     [0.1406, 0.1406, 0.1406, 0.1406, 0.1406, 0.140...
# 2     [0.1523, 0.1523, 0.1523, 0.1523, 0.1523, 0.160...
# 3     [0.2188, 0.2188, 0.1953, 0.1953, 0.1953, 0.195...
# 4     [0.1875, 0.1563, 0.1563, 0.1563, 0.1563, 0.156...
# ...                                                 ...
# 3825  [0.168, 0.168, 0.1602, 0.1563, 0.1563, 0.1563,...
# 3826  [0.168, 0.168, 0.168, 0.168, 0.168, 0.168, 0.1...
# 3827  [0.168, 0.168, 0.168, 0.168, 0.168, 0.1641, 0....
# 3828  [0.1523, 0.1523, 0.1523, 0.1523, 0.1523, 0.152...
# 3829  [0.1602, 0.1602, 0.1602, 0.1602, 0.1641, 0.164...
#
#                                    GM.obd.spd_veh.value
# 0     [31.04, 31.0, 30.970000000000002, 31.470000000...
# 1     [29.52, 29.48, 29.42, 29.400000000000002, 29.3...
# 2     [30.080000000000002, 30.14, 30.2, 30.23, 29.54...
# 3     [36.910000000000004, 37.0, 37.07, 37.18, 37.25...
# 4     [41.2, 41.27, 41.38, 41.46, 41.53, 40.76, 41.6...
# ...                                                 ...
# 3825  [12.68, 13.44, 13.49, 13.540000000000001, 13.5...
# 3826  [18.56, 18.53, 18.52, 18.51, 18.49000000000000...
# 3827  [11.77, 11.72, 11.68, 11.64, 11.4, 11.37000000...
# 3828  [7.22, 6.79, 6.76, 6.74, 6.69, 6.67, 6.63, 6.6...
# 3829  [6.49, 7.17, 6.45, 6.41, 6.38, 6.3500000000000...
#
# [3830 rows x 10 columns]

# %%
print('For the first 5 rows (of 100m each), print number of measurements: ')
print('z-axis:       ', [df['GM.acc.xyz.z'][i].shape for i in range(0,6)])
print('speed:        ', [df['GM.obd.spd_veh.value'][i].shape for i in range(0,6)])
print('IRI_sequence: ', [df['IRI_sequence'][i].shape for i in range(0,6)])

print('\n\n I.e. each variable cell contain an array of varying length (!)')
# Out:
# For the first 5 rows (of 100m each), print number of measurements:
# z-axis:        [(2539,), (2661,), (2507,), (2396,), (2355,), (2536,)]
# speed:         [(461,), (484,), (455,), (426,), (424,), (459,)]
# IRI_sequence:  [(10,), (10,), (10,), (10,), (10,), (10,)]
#
#
#  I.e. each variable cell contain an array of varying length (!)

# %% [markdown]
# ### Exploring z-variable

# %% [markdown]
# Let's plot the first 100 observations of the first row. It is seen that the z-variable is inherently discrete.

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Acceleration of first 100m')
axs[0].plot(df0['GM.acc.xyz.z'][0][0:100])
axs[1].plot(df0['GM.acc.xyz.z'][0])

# %%
plt.plot([df['GM.acc.xyz.z'][i][0] for i in range(1,n)]);
plt.title("Initial Z of every first 100m");

# %% [markdown]
# ## Data visualisations

# %% [markdown]
# ### IRI-mean

# %% [markdown]
# Below, the IRI-mean values are plotted. A threshold value of IRI=5 seems reasonable to distinguish anomalies.

# %%
plt.hist(df['IRI_mean'], bins=20);
plt.axvline(x=5, color='r', linestyle='dashed', linewidth=2)

# %% [markdown]
# ### Speed

# %%
fig, ax = plt.subplots(2)
ax[0].plot(df['GM.obd.spd_veh.value'][0])
ax[0].set_title("Speed the first 100m");

ax[1].plot([df['GM.obd.spd_veh.value'][i][0] for i in range(1,n)])
ax[1].set_title("Initial speed of every 100m");
